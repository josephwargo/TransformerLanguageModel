# %%
import numpy as np
import baseRNN
from datasets import load_dataset
import re
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Dataset

# %%
# constants
START_TOKEN = '<START>'
END_TOKEN = '<END>'
NUM_SAMPLES = 10000
imdbDataset = load_dataset("stanfordnlp/imdb")

embeddingsFilepath = '/Users/josep/Desktop/Self/Learning/NLP/RNN/data/glove.6B.300d.txt'

# helper functions
def read_corpus(dataset):
    files = dataset["train"]["text"][:NUM_SAMPLES]
    return [[START_TOKEN] + [re.sub(r'[^\w]', '', w.lower()) for w in f.split(" ")] + [END_TOKEN] for f in files]


def embedding_for_vocab(filepath, words, dimensions):
    vocab_size = len(words)
    embeddings = np.zeros((vocab_size, dimensions))

    with open(filepath, encoding="utf8") as f:
        for line in f:
            word, *vector = line.split()
            if word in words.keys():
                index = words[word]
                embeddings[index] = np.array(vector)[:dimensions]
    return embeddings

imdbCorpus = read_corpus(imdbDataset)

corpusWords = [y for x in imdbCorpus for y in x]
corpusWords = list(set(corpusWords))
word2ind={}
for i in range(len(corpusWords)+1):
    word2ind[corpusWords[i-1]] = i
word2ind['<PAD>'] = 0
embeddings = embedding_for_vocab(embeddingsFilepath, word2ind, 300)

# %% [markdown]
# ### Batching Testing

# %%
testText = np.array(imdbCorpus[0])
mapper = np.vectorize(word2ind.get)
result = mapper(testText)
# result

# %%
len(imdbCorpus[0])%3

len(imdbCorpus[0][:-2])%3
# Out:
# 0

# %% [markdown]
# ### Training

# %%
testRNN = baseRNN.neuralNet(embeddings=embeddings, word2ind=word2ind, outputActivation='softmax',
                            hiddenLayerShapes=[100,100,100], hiddenLayerActivations=['relu', 'relu', 'relu'],
                            lossFunction='crossEntropyLoss', learningRate=.0005, epochs=1, batchSize=5,
                            adam=True, clipVal=1, debug=False)

# %%
# overfitCorpus = [imdbCorpus[0][0:20]] * 10
# # overfitCorpus = [overfitCorpus, overfitCorpus]
testCorpus = imdbCorpus[:1000]
# testCorpus

# %%
testRNN.trainModel(imdbCorpus)
# Out:
# Batch #1 - max 313 words
# Loss: 7.149708925820669
# ********************************************
#
# Batch #2 - max 482 words
# Loss: 7.003461507929369
# ********************************************
#
# Batch #3 - max 362 words
# Loss: 7.065856685189443
# ********************************************
#
# Batch #4 - max 890 words
# Loss: 7.059179964215564
# ********************************************
#
# Batch #5 - max 327 words
# Loss: 7.031967544594431
# ********************************************
#
# Batch #6 - max 371 words
# Loss: 6.966663970069166
# ********************************************
#
# Batch #7 - max 387 words
# Loss: 6.9470779439311725
# ********************************************
#
# Batch #8 - max 298 words
# Loss: 6.435090351324915
# ********************************************
#
# Batch #9 - max 839 words
# Loss: 7.01214404493116
# ********************************************
#
# Batch #10 - max 159 words
# Loss: 6.407117246440796
# ********************************************
#
# Batch #11 - max 464 words
# Loss: 7.0352325694237186
# ********************************************
#
# Batch #12 - max 460 words
# Loss: 6.83455772990449
# ********************************************
#
# Batch #13 - max 328 words
# Loss: 6.449220967175552
# ********************************************
#
# Batch #14 - max 772 words
# Loss: 6.9572071846345205
# ********************************************
#
# Batch #15 - max 366 words
# Loss: 7.082654182301298
# ********************************************
#
# Batch #16 - max 353 words
# Loss: 6.690301592833205
# ********************************************
#
# Batch #17 - max 631 words
# Loss: 7.014869576070756
# ********************************************
#
# Batch #18 - max 591 words
# Loss: 6.710777080964411
# ********************************************
#
# Batch #19 - max 867 words
# Loss: 7.001143460742513
# ********************************************
#
# Batch #20 - max 522 words
# Loss: 6.928160025375135
# ********************************************
#
# Batch #21 - max 257 words
# Loss: 6.640913920859738
# ********************************************
#
# Batch #22 - max 278 words
# Loss: 6.480397929280625
# ********************************************
#
# Batch #23 - max 502 words
# Loss: 6.9262978732401095
# ********************************************
#
# Batch #24 - max 333 words
# Loss: 6.604027532341842
# ********************************************
#
# Batch #25 - max 324 words
# Loss: 6.588454967166585
# ********************************************
#
# Batch #26 - max 865 words
# Loss: 6.783427161431778
# ********************************************
#
# Batch #27 - max 308 words
# Loss: 6.7195877223589955
# ********************************************
#
# Batch #28 - max 263 words
# Loss: 6.853488386707646
# ********************************************
#
# Batch #29 - max 596 words
# Loss: 7.197313374312602
# ********************************************
#
# Batch #30 - max 428 words
# Loss: 7.099343975886507
# ********************************************
#
# Batch #31 - max 193 words
# Loss: 7.047472335673824
# ********************************************
#
# Batch #32 - max 254 words
# Loss: 6.699125370296806
# ********************************************
#
# Batch #33 - max 260 words
# Loss: 6.709823475469568
# ********************************************
#
# Batch #34 - max 381 words
# Loss: 6.952765162683953
# ********************************************
#
# Batch #35 - max 266 words
# Loss: 6.843989340068084
# ********************************************
#
# Batch #36 - max 333 words
# Loss: 6.894707919209142
# ********************************************
#
# Batch #37 - max 915 words
# Loss: 7.05769820875216
# ********************************************
#
# Batch #38 - max 228 words
# Loss: 6.826250977817145
# ********************************************
#
# Batch #39 - max 216 words
# Loss: 6.702752525260248
# ********************************************
#
# Batch #40 - max 908 words
# Loss: 7.121965444712259
# ********************************************
#
# Batch #41 - max 376 words
# Loss: 6.990065864216244
# ********************************************
#
# Batch #42 - max 652 words
# Loss: 6.371298053740635
# ********************************************
#
# Batch #43 - max 457 words
# Loss: 6.715479398319361
# ********************************************
#
# Batch #44 - max 498 words
# Loss: 6.949133330155333
# ********************************************
#
# Batch #45 - max 158 words
# Loss: 7.061458359266624
# ********************************************
#
# Batch #46 - max 306 words
# Loss: 6.926406050030241
# ********************************************
#
# Batch #47 - max 1001 words
# Loss: 7.266747440914686
# ********************************************
#
# Batch #48 - max 537 words
# Loss: 6.838636620655587
# ********************************************
#
# Batch #49 - max 152 words
# Loss: 6.3579491367605
# ********************************************
#
# Batch #50 - max 838 words
# Loss: 6.5738226177283225
# ********************************************
#
# Batch #51 - max 768 words
# Loss: 6.781919655787363
# ********************************************
#
# Batch #52 - max 411 words
# Loss: 6.882198057828232
# ********************************************
#
# Batch #53 - max 366 words
# Loss: 6.801915826451034
# ********************************************
#
# Batch #54 - max 856 words
# Loss: 6.970459132231956
# ********************************************
#
# Batch #55 - max 434 words
# Loss: 6.9112035685196185
# ********************************************
#
# Batch #56 - max 270 words
# Loss: 6.788793782866204
# ********************************************
#
# Batch #57 - max 813 words
# Loss: 7.005412441358658
# ********************************************
#
# Batch #58 - max 174 words
# Loss: 6.811610873371364
# ********************************************
#
# Batch #59 - max 316 words
# Loss: 7.0141006383019535
# ********************************************
#
# Batch #60 - max 424 words
# Loss: 6.911870453414808
# ********************************************
#
# Batch #61 - max 258 words
# Loss: 6.930601068409474
# ********************************************
#
# Batch #62 - max 309 words
# Loss: 6.686066558925727
# ********************************************
#
# Batch #63 - max 395 words
# Loss: 6.7881765456142045
# ********************************************
#
# Batch #64 - max 297 words
# Loss: 6.5927162941836155
# ********************************************
#
# Batch #65 - max 165 words
# Loss: 6.8251439092488075
# ********************************************
#
# Batch #66 - max 154 words
# Loss: 6.342209797166534
# ********************************************
#
# Batch #67 - max 139 words
# Loss: 7.277645480977397
# ********************************************
#
# Batch #68 - max 199 words
# Loss: 6.780138614332292
# ********************************************
#
# Batch #69 - max 218 words
# Loss: 6.717316170078395
# ********************************************
#
# Batch #70 - max 435 words
# Loss: 6.830231865754354
# ********************************************
#
# Batch #71 - max 529 words
# Loss: 6.866496386175758
# ********************************************
#
# Batch #72 - max 358 words
# Loss: 6.855921770826976
# ********************************************
#
# Batch #73 - max 316 words
# Loss: 7.1582699317543215
# ********************************************
#
# Batch #74 - max 275 words
# Loss: 6.9763940166257115
# ********************************************
#
# Batch #75 - max 536 words
# Loss: 6.847459181321645
# ********************************************
#
# Batch #76 - max 565 words
# Loss: 6.87281063209602
# ********************************************
#
# Batch #77 - max 222 words
# Loss: 6.589873800602924
# ********************************************
#
# Batch #78 - max 350 words
# Loss: 7.088081170221557
# ********************************************
#
# Batch #79 - max 757 words
# Loss: 7.085527121997786
# ********************************************
#
# Batch #80 - max 341 words
# Loss: 6.822769171400938
# ********************************************
#
# Batch #81 - max 142 words
# Loss: 7.045590352494732
# ********************************************
#
# Batch #82 - max 193 words
# Loss: 6.9772029605101915
# ********************************************
#
# Batch #83 - max 527 words
# Loss: 6.929332074328533
# ********************************************
#
# Batch #84 - max 493 words
# Loss: 6.922552722413551
# ********************************************
#
# Batch #85 - max 793 words
# Loss: 6.983664067702263
# ********************************************
#
# Batch #86 - max 355 words
# Loss: 7.066013483517016
# ********************************************
#
# Batch #87 - max 329 words
# Loss: 6.43232072453576
# ********************************************
#
# Batch #88 - max 208 words
# Loss: 6.852572298594225
# ********************************************
#
# Batch #89 - max 435 words
# Loss: 7.293112708084656
# ********************************************
#
# Batch #90 - max 332 words
# Loss: 6.730636652927051
# ********************************************
#
# Batch #91 - max 336 words
# Loss: 6.7823696079229085
# ********************************************
#
# Batch #92 - max 972 words
# Loss: 7.077674380348315
# ********************************************
#
# Batch #93 - max 999 words
# Loss: 7.290563333903177
# ********************************************
#
# Batch #94 - max 247 words
# Loss: 6.704024357118839
# ********************************************
#
# Batch #95 - max 342 words
# Loss: 6.932033590765155
# ********************************************
#
# Batch #96 - max 748 words
# Loss: 6.906004943683175
# ********************************************
#
# Batch #97 - max 1016 words
# Loss: 7.000410226054004
# ********************************************
#
# Batch #98 - max 287 words
# Loss: 6.703893431121761
# ********************************************
#
# Batch #99 - max 235 words
# Loss: 6.843757443378836
# ********************************************
#
# Batch #100 - max 524 words
# Loss: 7.027996788641683
# ********************************************
#
# Batch #101 - max 718 words
# Loss: 7.164322123335329
# ********************************************
#
# Batch #102 - max 441 words
# Loss: 7.073741950021877
# ********************************************
#
# Batch #103 - max 166 words
# Loss: 7.044406179913817
# ********************************************
#
# Batch #104 - max 660 words
# Loss: 6.488099048044537
# ********************************************
#
# Batch #105 - max 570 words
# Loss: 7.161152266355159
# ********************************************
#
# Batch #106 - max 856 words
# Loss: 6.987387357079194
# ********************************************
#
# Batch #107 - max 387 words
# Loss: 6.6191289222195495
# ********************************************
#
# Batch #108 - max 359 words
# Loss: 6.707929398029241
# ********************************************
#
# Batch #109 - max 481 words
# Loss: 6.839892725779096
# ********************************************
#
# Batch #110 - max 296 words
# Loss: 6.629305890235697
# ********************************************
#
# Batch #111 - max 284 words
# Loss: 6.7341080102735305
# ********************************************
#
# Batch #112 - max 345 words
# Loss: 6.952867344877713
# ********************************************
#
# Batch #113 - max 355 words
# Loss: 6.858566500233361
# ********************************************
#
# Batch #114 - max 352 words
# Loss: 7.041353513849218
# ********************************************
#
# Batch #115 - max 352 words
# Loss: 6.798705816252501
# ********************************************
#
# Batch #116 - max 227 words
# Loss: 6.830660689184226
# ********************************************
#
# Batch #117 - max 506 words
# Loss: 6.876745510889697
# ********************************************
#
# Batch #118 - max 276 words
# Loss: 7.015411035722148
# ********************************************
#
# Batch #119 - max 435 words
# Loss: 7.0342129368691255
# ********************************************
#
# Batch #120 - max 287 words
# Loss: 6.604656285793868
# ********************************************
#
# Batch #121 - max 458 words
# Loss: 6.570367368913016
# ********************************************
#
# Batch #122 - max 357 words
# Loss: 7.113799062352707
# ********************************************
#
# Batch #123 - max 989 words
# Loss: 7.091474849806866
# ********************************************
#
# Batch #124 - max 561 words
# Loss: 6.751815372667754
# ********************************************
#
# Batch #125 - max 199 words
# Loss: 6.612567730431146
# ********************************************
#
# Batch #126 - max 184 words
# Loss: 6.8140933927110865
# ********************************************
#
# Batch #127 - max 246 words
# Loss: 6.951325041987889
# ********************************************
#
# Batch #128 - max 352 words
# Loss: 7.064269486721943
# ********************************************
#
# Batch #129 - max 385 words
# Loss: 6.6741215615255
# ********************************************
#
# Batch #130 - max 167 words
# Loss: 6.81000773886979
# ********************************************
#
# Batch #131 - max 932 words
# Loss: 6.7333180656579135
# ********************************************
#
# Batch #132 - max 993 words
# Loss: 7.126831618104301
# ********************************************
#
# Batch #133 - max 433 words
# Loss: 6.621272635832359
# ********************************************
#
# Batch #134 - max 941 words
# Loss: 7.116338111332529
# ********************************************
#
# Batch #135 - max 455 words
# Loss: 7.038090182113499
# ********************************************
#
# Batch #136 - max 168 words
# Loss: 6.827586691111575
# ********************************************
#
# Batch #137 - max 939 words
# Loss: 6.973237477097451
# ********************************************
#
# Batch #138 - max 770 words
# Loss: 7.065518155660802
# ********************************************
#
# Batch #139 - max 286 words
# Loss: 6.515243660333701
# ********************************************
#
# Batch #140 - max 257 words
# Loss: 6.90039793102809
# ********************************************
#
# Batch #141 - max 722 words
# Loss: 6.835748604747122
# ********************************************
#
# Batch #142 - max 478 words
# Loss: 6.716234352380988
# ********************************************
#
# Batch #143 - max 298 words
# Loss: 6.658575322721165
# ********************************************
#
# Batch #144 - max 264 words
# Loss: 6.851820650518852
# ********************************************
#
# Batch #145 - max 357 words
# Loss: 7.0302890174730726
# ********************************************
#
# Batch #146 - max 746 words
# Loss: 6.834827339821135
# ********************************************
#
# Batch #147 - max 198 words
# Loss: 7.0489412758165395
# ********************************************
#
# Batch #148 - max 458 words
# Loss: 6.5966741866303416
# ********************************************
#
# Batch #149 - max 447 words
# Loss: 6.552706330298928
# ********************************************
#
# Batch #150 - max 748 words
# Loss: 6.681922172987835
# ********************************************
#
# Batch #151 - max 802 words
# Loss: 6.6624311487657835
# ********************************************
#
# Batch #152 - max 528 words
# Loss: 6.872201882658319
# ********************************************
#
# Batch #153 - max 466 words
# Loss: 6.472666128323644
# ********************************************
#
# Batch #154 - max 447 words
# Loss: 6.976821589911348
# ********************************************
#
# Batch #155 - max 991 words
# Loss: 6.923261341297316
# ********************************************
#
# Batch #156 - max 480 words
# Loss: 6.924550766095228
# ********************************************
#
# Batch #157 - max 381 words
# Loss: 7.221577282013803
# ********************************************
#
# Batch #158 - max 478 words
# Loss: 6.637751344729515
# ********************************************
#
# Batch #159 - max 196 words
# Loss: 6.972500523437788
# ********************************************
#
# Batch #160 - max 401 words
# Loss: 7.064098277244906
# ********************************************
#
# Batch #161 - max 750 words
# Loss: 7.214133774184367
# ********************************************
#
# Batch #162 - max 337 words
# Loss: 6.604822275058588
# ********************************************
#
# Batch #163 - max 461 words
# Loss: 6.518845247366895
# ********************************************
#
# Batch #164 - max 275 words
# Loss: 6.3607402238285236
# ********************************************
#
# Batch #165 - max 311 words
# Loss: 7.095515731488347
# ********************************************
#
# Batch #166 - max 839 words
# Loss: 7.4460967999494425
# ********************************************
#
# Batch #167 - max 507 words
# Loss: 6.701447637079701
# ********************************************
#
# Batch #168 - max 209 words
# Loss: 6.835808719437976
# ********************************************
#
# Batch #169 - max 238 words
# Loss: 6.90885281127426
# ********************************************
#
# Batch #170 - max 873 words
# Loss: 7.14445231757938
# ********************************************
#
# Batch #171 - max 174 words
# Loss: 6.7346906644662115
# ********************************************
#
# Batch #172 - max 293 words
# Loss: 7.143773489021507
# ********************************************
#
# Batch #173 - max 295 words
# Loss: 6.910226517240476
# ********************************************
#
# Batch #174 - max 292 words
# Loss: 6.9763768545805025
# ********************************************
#
# Batch #175 - max 245 words
# Loss: 6.6827704248638735
# ********************************************
#
# Batch #176 - max 478 words
# Loss: 6.90054962372066
# ********************************************
#
# Batch #177 - max 206 words
# Loss: 6.435366724595341
# ********************************************
#
# Batch #178 - max 307 words
# Loss: 6.865811279670649
# ********************************************
#
# Batch #179 - max 233 words
# Loss: 6.97806680329301
# ********************************************
#
# Batch #180 - max 470 words
# Loss: 7.0634795641963875
# ********************************************
#
# Batch #181 - max 259 words
# Loss: 6.604069264611546
# ********************************************
#
# Batch #182 - max 214 words
# Loss: 6.804289555918685
# ********************************************
#
# Batch #183 - max 461 words
# Loss: 6.747609928857136
# ********************************************
#
# Batch #184 - max 344 words
# Loss: 6.944067705853364
# ********************************************
#
# Batch #185 - max 486 words
# Loss: 6.882956176643615
# ********************************************
#
# Batch #186 - max 997 words
# Loss: 6.662143197179351
# ********************************************
#
# Batch #187 - max 536 words
# Loss: 6.734297223475564
# ********************************************
#
# Batch #188 - max 407 words
# Loss: 6.913084096591138
# ********************************************
#
# Batch #189 - max 992 words
# Loss: 7.104036040983631
# ********************************************
#
# Batch #190 - max 265 words
# Loss: 6.473423361600224
# ********************************************
#
# Batch #191 - max 395 words
# Loss: 6.578462922015929
# ********************************************
#
# Batch #192 - max 413 words
# Loss: 7.005089959782225
# ********************************************
#
# Batch #193 - max 240 words
# Loss: 6.722919395808039
# ********************************************
#
# Batch #194 - max 517 words
# Loss: 7.145889092099721
# ********************************************
#
# Batch #195 - max 626 words
# Loss: 6.953900644688991
# ********************************************
#
# Batch #196 - max 215 words
# Loss: 6.835943317781629
# ********************************************
#
# Batch #197 - max 572 words
# Loss: 6.854308365431981
# ********************************************
#
# Batch #198 - max 514 words
# Loss: 6.7632152083599255
# ********************************************
#
# Batch #199 - max 177 words
# Loss: 6.757302484446305
# ********************************************
#
# Batch #200 - max 268 words
# Loss: 6.862614377239838
# ********************************************
#
# Batch #201 - max 729 words
# Loss: 7.891085703985522
# ********************************************
#
# Batch #202 - max 188 words
# Loss: 6.562465716656153
# ********************************************
#
# Batch #203 - max 182 words
# Loss: 7.050810039266895
# ********************************************
#
# Batch #204 - max 512 words
# Loss: 7.337373866162627
# ********************************************
#
# Batch #205 - max 634 words
# Loss: 7.67137835731363
# ********************************************
#
# Batch #206 - max 736 words
# Loss: 7.557400120048902
# ********************************************
#
# Batch #207 - max 373 words
# Loss: 7.2813382515248355
# ********************************************
#
# Batch #208 - max 172 words
# Loss: 7.110350673149193
# ********************************************
#
# Batch #209 - max 506 words
# Loss: 7.14862519238042
# ********************************************
#
# Batch #210 - max 206 words
# Loss: 7.201928354029401
# ********************************************
#
# Batch #211 - max 183 words
# Loss: 6.672405313586
# ********************************************
#
# Batch #212 - max 375 words
# Loss: 7.262927927843365
# ********************************************
#
# Batch #213 - max 174 words
# Loss: 6.594868587371458
# ********************************************
#
# Batch #214 - max 263 words
# Loss: 7.205433662005217
# ********************************************
#
# Batch #215 - max 262 words
# Loss: 7.008982929609845
# ********************************************
#
# Batch #216 - max 573 words
# Loss: 7.85663111568108
# ********************************************
#
# Batch #217 - max 415 words
# Loss: 7.298689421077949
# ********************************************
#
# Batch #218 - max 348 words
# Loss: 7.615622029149053
# ********************************************
#
# Batch #219 - max 421 words
# Loss: 6.876590430837808
# ********************************************
#
# Batch #220 - max 181 words
# Loss: 7.192637234742213
# ********************************************
#
# Batch #221 - max 413 words
# Loss: 6.995568597797896
# ********************************************
#
# Batch #222 - max 647 words
# Loss: 7.206754651120302
# ********************************************
#
# Batch #223 - max 405 words
# Loss: 7.181211937722612
# ********************************************
#
# Batch #224 - max 256 words
# Loss: 7.2181076039320695
# ********************************************
#
# Batch #225 - max 371 words
# Loss: 7.402030639401833
# ********************************************
#
# Batch #226 - max 1265 words
# Loss: 7.5175571586097085
# ********************************************
#
# Batch #227 - max 423 words
# Loss: 7.072126799231813
# ********************************************
#
# Batch #228 - max 195 words
# Loss: 6.861438766223855
# ********************************************
#
# Batch #229 - max 211 words
# Loss: 7.229625953179803
# ********************************************
#
# Batch #230 - max 599 words
# Loss: 7.031698534961938
# ********************************************
#
# Batch #231 - max 238 words
# Loss: 6.846893490544568
# ********************************************
#
# Batch #232 - max 258 words
# Loss: 6.86434869451576
# ********************************************
#
# Batch #233 - max 331 words
# Loss: 7.246687113479724
# ********************************************
#
# Batch #234 - max 399 words
# Loss: 6.763815797516291
# ********************************************
#
# Batch #235 - max 1012 words
# Loss: 7.8475185401143275
# ********************************************
#
# Batch #236 - max 679 words
# Loss: 7.444839663132361
# ********************************************
#
# Batch #237 - max 651 words
# Loss: 6.951124037043104
# ********************************************
#
# Batch #238 - max 368 words
# Loss: 6.823900292310065
# ********************************************
#
# Batch #239 - max 118 words
# Loss: 7.04179351952618
# ********************************************
#
# Batch #240 - max 827 words
# Loss: 7.149451652056124
# ********************************************
#
# Batch #241 - max 401 words
# Loss: 7.037585650610535
# ********************************************
#
# Batch #242 - max 306 words
# Loss: 6.819309383367187
# ********************************************
#
# Batch #243 - max 497 words
# Loss: 7.390032900098847
# ********************************************
#
# Batch #244 - max 597 words
# Loss: 7.161265652948366
# ********************************************
#
# Batch #245 - max 296 words
# Loss: 7.179897219182704
# ********************************************
#
# Batch #246 - max 441 words
# Loss: 7.311204666616008
# ********************************************
#
# Batch #247 - max 650 words
# Loss: 7.4282726854108425
# ********************************************
#
# Batch #248 - max 264 words
# Loss: 6.4727860446596885
# ********************************************
#
# Batch #249 - max 875 words
# Loss: 7.346264332701091
# ********************************************
#
# Batch #250 - max 382 words
# Loss: 6.893046277618076
# ********************************************
#
# Batch #251 - max 250 words
# Loss: 7.083214470915738
# ********************************************
#
# Batch #252 - max 266 words
# Loss: 6.967723269376532
# ********************************************
#
# Batch #253 - max 553 words
# Loss: 7.153966604117492
# ********************************************
#
# Batch #254 - max 553 words
# Loss: 6.966035260734335
# ********************************************
#
# Batch #255 - max 330 words
# Loss: 6.827950197548279
# ********************************************
#
# Batch #256 - max 336 words
# Loss: 7.07961627122095
# ********************************************
#
# Batch #257 - max 991 words
# Loss: 7.321760419797073
# ********************************************
#
# Batch #258 - max 354 words
# Loss: 7.248383962002289
# ********************************************
#
# Batch #259 - max 341 words
# Loss: 7.197591350019625
# ********************************************
#
# Batch #260 - max 348 words
# Loss: 7.088433747713594
# ********************************************
#
# Batch #261 - max 327 words
# Loss: 7.210014046834382
# ********************************************
#
# Batch #262 - max 611 words
# Loss: 7.347901314678341
# ********************************************
#
# Batch #263 - max 222 words
# Loss: 6.96326610757873
# ********************************************
#
# Batch #264 - max 326 words
# Loss: 7.3884586588390295
# ********************************************
#
# Batch #265 - max 368 words
# Loss: 6.98675968431755
# ********************************************
#
# Batch #266 - max 311 words
# Loss: 7.136972953178595
# ********************************************
#
# Batch #267 - max 570 words
# Loss: 6.910709853012988
# ********************************************
#
# Batch #268 - max 554 words
# Loss: 7.482902711610757
# ********************************************
#
# Batch #269 - max 580 words
# Loss: 7.055271349402886
# ********************************************
#
# Batch #270 - max 400 words
# Loss: 7.188201409927983
# ********************************************
#
# Batch #271 - max 341 words
# Loss: 7.208713107879574
# ********************************************
#
# Batch #272 - max 229 words
# Loss: 7.0158461288235605
# ********************************************
#
# Batch #273 - max 594 words
# Loss: 7.275151735466871
# ********************************************
#
# Batch #274 - max 292 words
# Loss: 7.022527852763349
# ********************************************
#
# Batch #275 - max 723 words
# Loss: 7.604539371949742
# ********************************************
#
# Batch #276 - max 233 words
# Loss: 6.8929549469111
# ********************************************
#
# Batch #277 - max 322 words
# Loss: 7.297323989306176
# ********************************************
#
# Batch #278 - max 270 words
# Loss: 6.874966494274262
# ********************************************
#
# Batch #279 - max 469 words
# Loss: 7.100813289277399
# ********************************************
#
# Batch #280 - max 413 words
# Loss: 6.710602421025848
# ********************************************
#
# Batch #281 - max 632 words
# Loss: 7.100237380340248
# ********************************************
#
# Batch #282 - max 440 words
# Loss: 7.00806682048401
# ********************************************
#
# Batch #283 - max 321 words
# Loss: 6.855917487458996
# ********************************************
#
# Batch #284 - max 220 words
# Loss: 6.998823319977829
# ********************************************
#
# Batch #285 - max 102 words
# Loss: 6.683937695347009
# ********************************************
#
# Batch #286 - max 498 words
# Loss: 6.919407251464343
# ********************************************
#
# Batch #287 - max 837 words
# Loss: 7.233481353387076
# ********************************************
#
# Batch #288 - max 420 words
# Loss: 7.2935904801124405
# ********************************************
#
# Batch #289 - max 534 words
# Loss: 6.822690056572053
# ********************************************
#
# Batch #290 - max 735 words
# Loss: 7.289936865667854
# ********************************************
#
# Batch #291 - max 512 words
# Loss: 7.352559885590641
# ********************************************
#
# Batch #292 - max 569 words
# Loss: 6.979132371845903
# ********************************************
#
# Batch #293 - max 277 words
# Loss: 6.900403640961454
# ********************************************
#
# Batch #294 - max 580 words
# Loss: 7.444934051681363
# ********************************************
#
# Batch #295 - max 378 words
# Loss: 7.633545586241749
# ********************************************
#
# Batch #296 - max 768 words
# Loss: 7.098726711841133
# ********************************************
#
# Batch #297 - max 412 words
# Loss: 7.310977246767344
# ********************************************
#
# Batch #298 - max 302 words
# Loss: 6.821379129094624
# ********************************************
#
# Batch #299 - max 529 words
# Loss: 7.096507714574809
# ********************************************
#
# Batch #300 - max 177 words
# Loss: 6.997805517716725
# ********************************************
#
# Batch #301 - max 269 words
# Loss: 6.9994217855875025
# ********************************************
#
# Batch #302 - max 386 words
# Loss: 7.103051015911507
# ********************************************
#
# Batch #303 - max 470 words
# Loss: 7.118620373023811
# ********************************************
#
# Batch #304 - max 297 words
# Loss: 7.037414657523394
# ********************************************
#
# Batch #305 - max 824 words
# Loss: 7.071894294043675
# ********************************************
#
# Batch #306 - max 358 words
# Loss: 7.582907382340187
# ********************************************
#
# Batch #307 - max 370 words
# Loss: 7.091094785535101
# ********************************************
#
# Batch #308 - max 218 words
# Loss: 7.269674625526861
# ********************************************
#
# Batch #309 - max 398 words
# Loss: 6.953808725587763
# ********************************************
#
# Batch #310 - max 879 words
# Loss: 6.984283692279063
# ********************************************
#
# Batch #311 - max 258 words
# Loss: 7.053214459002078
# ********************************************
#
# Batch #312 - max 173 words
# Loss: 6.798791520275177
# ********************************************
#
# Batch #313 - max 460 words
# Loss: 7.004767723602357
# ********************************************
#
# Batch #314 - max 593 words
# Loss: 7.251343620156856
# ********************************************
#
# Batch #315 - max 473 words
# Loss: 7.362216000158769
# ********************************************
#
# Batch #316 - max 244 words
# Loss: 7.121965372447232
# ********************************************
#
# Batch #317 - max 378 words
# Loss: 7.072793377264317
# ********************************************
#
# Batch #318 - max 970 words
# Loss: 8.039329126090065
# ********************************************
#
# Batch #319 - max 891 words
# Loss: 7.675204024891633
# ********************************************
#
# Batch #320 - max 378 words
# Loss: 7.181290986753315
# ********************************************
#
# Batch #321 - max 323 words
# Loss: 7.055368810675145
# ********************************************
#
# Batch #322 - max 734 words
# Loss: 7.493222569241042
# ********************************************
#
# Batch #323 - max 275 words
# Loss: 6.956664978150292
# ********************************************
#
# Batch #324 - max 301 words
# Loss: 6.662801796258099
# ********************************************
#
# Batch #325 - max 387 words
# Loss: 7.143077977510796
# ********************************************
#
# Batch #326 - max 152 words
# Loss: 6.698196913169559
# ********************************************
#
# Batch #327 - max 140 words
# Loss: 6.761576069408721
# ********************************************
#
# Batch #328 - max 244 words
# Loss: 6.758269315799098
# ********************************************
#
# Batch #329 - max 284 words
# Loss: 6.896912475512749
# ********************************************
#
# Batch #330 - max 206 words
# Loss: 6.8102057378533996
# ********************************************
#
# Batch #331 - max 538 words
# Loss: 6.859337861382946
# ********************************************
#
# Batch #332 - max 277 words
# Loss: 6.896578528056443
# ********************************************
#
# Batch #333 - max 483 words
# Loss: 6.771215974262835
# ********************************************
#
# Batch #334 - max 602 words
# Loss: 6.96767405751993
# ********************************************
#
# Batch #335 - max 532 words
# Loss: 6.845984774173421
# ********************************************
#
# Batch #336 - max 221 words
# Loss: 7.0576662152572744
# ********************************************
#
# Batch #337 - max 407 words
# Loss: 6.762281818247425
# ********************************************
#
# Batch #338 - max 369 words
# Loss: 7.035023158397707
# ********************************************
#
# Batch #339 - max 279 words
# Loss: 6.712350498452219
# ********************************************
#
# Batch #340 - max 268 words
# Loss: 6.972827351535858
# ********************************************
#
# Batch #341 - max 390 words
# Loss: 7.14580121757346
# ********************************************
#
# Batch #342 - max 344 words
# Loss: 6.944321694956657
# ********************************************
#
# Batch #343 - max 371 words
# Loss: 7.213436122653051
# ********************************************
#
# Batch #344 - max 284 words
# Loss: 7.503418239306281
# ********************************************
#
# Batch #345 - max 331 words
# Loss: 7.5021684904190975
# ********************************************
#
# Batch #346 - max 585 words
# Loss: 6.974596559314739
# ********************************************
#
# Batch #347 - max 248 words
# Loss: 6.846855169871932
# ********************************************
#
# Batch #348 - max 295 words
# Loss: 7.296658695937197
# ********************************************
#
# Batch #349 - max 248 words
# Loss: 6.777769374902749
# ********************************************
#
# Batch #350 - max 454 words
# Loss: 7.177200172936741
# ********************************************
#
# Batch #351 - max 228 words
# Loss: 7.246556260690821
# ********************************************
#
# Batch #352 - max 536 words
# Loss: 6.775375834064854
# ********************************************
#
# Batch #353 - max 198 words
# Loss: 6.402742344077561
# ********************************************
#
# Batch #354 - max 229 words
# Loss: 6.70044888666148
# ********************************************
#
# Batch #355 - max 675 words
# Loss: 7.120549810944945
# ********************************************
#
# Batch #356 - max 533 words
# Loss: 7.022905914440384
# ********************************************
#
# Batch #357 - max 173 words
# Loss: 6.5912360061479776
# ********************************************
#
# Batch #358 - max 447 words
# Loss: 7.005711055151989
# ********************************************
#
# Batch #359 - max 217 words
# Loss: 6.816869962212365
# ********************************************
#
# Batch #360 - max 225 words
# Loss: 6.9207765507461945
# ********************************************
#
# Batch #361 - max 163 words
# Loss: 7.275552327971697
# ********************************************
#
# Batch #362 - max 600 words
# Loss: 6.976941035916639
# ********************************************
#
# Batch #363 - max 550 words
# Loss: 7.113740625620977
# ********************************************
#
# Batch #364 - max 365 words
# Loss: 6.868785255623433
# ********************************************
#
# Batch #365 - max 315 words
# Loss: 6.900749199718639
# ********************************************
#
# Batch #366 - max 453 words
# Loss: 6.867098316814729
# ********************************************
#
# Batch #367 - max 500 words
# Loss: 7.208422951502133
# ********************************************
#
# Batch #368 - max 376 words
# Loss: 7.192207579547916
# ********************************************
#
# Batch #369 - max 325 words
# Loss: 6.9370935134308995
# ********************************************
#
# Batch #370 - max 290 words
# Loss: 6.710452965309505
# ********************************************
#
# Batch #371 - max 596 words
# Loss: 6.938199318114295
# ********************************************
#
# Batch #372 - max 164 words
# Loss: 6.582728374237722
# ********************************************
#
# Batch #373 - max 334 words
# Loss: 6.82242416055946
# ********************************************
#
# Batch #374 - max 267 words
# Loss: 6.953721448063943
# ********************************************
#
# Batch #375 - max 388 words
# Loss: 6.714571695038197
# ********************************************
#
# Batch #376 - max 471 words
# Loss: 6.817065319420898
# ********************************************
#
# Batch #377 - max 305 words
# Loss: 6.693525297067256
# ********************************************
#
# Batch #378 - max 233 words
# Loss: 6.769991460951685
# ********************************************
#
# Batch #379 - max 511 words
# Loss: 7.124660829087606
# ********************************************
#
# Batch #380 - max 496 words
# Loss: 7.518318014609312
# ********************************************
#
# Batch #381 - max 990 words
# Loss: 7.598964158317377
# ********************************************
#
# Batch #382 - max 673 words
# Loss: 7.25785801393259
# ********************************************
#
# Batch #383 - max 476 words
# Loss: 6.760771124312152
# ********************************************
#
# Batch #384 - max 529 words
# Loss: 6.723257598903611
# ********************************************
#
# Batch #385 - max 150 words
# Loss: 6.578262406696595
# ********************************************
#
# Batch #386 - max 489 words
# Loss: 6.804811456956388
# ********************************************
#
# Batch #387 - max 224 words
# Loss: 6.462367010248883
# ********************************************
#
# Batch #388 - max 590 words
# Loss: 7.108039886871883
# ********************************************
#
# Batch #389 - max 340 words
# Loss: 6.971031404492456
# ********************************************
#
# Batch #390 - max 451 words
# Loss: 7.302992861948375
# ********************************************
#
# Batch #391 - max 217 words
# Loss: 7.036115029907346
# ********************************************
#
# Batch #392 - max 337 words
# Loss: 6.9668186631514475
# ********************************************
#
# Batch #393 - max 240 words
# Loss: 6.482823280446965
# ********************************************
#
# Batch #394 - max 938 words
# Loss: 7.429163366340384
# ********************************************
#
# Batch #395 - max 366 words
# Loss: 7.193876622577602
# ********************************************
#
# Batch #396 - max 168 words
# Loss: 6.642365508580806
# ********************************************
#
# Batch #397 - max 282 words
# Loss: 6.7396168868539705
# ********************************************
#
# Batch #398 - max 477 words
# Loss: 7.216049479813567
# ********************************************
#
# Batch #399 - max 177 words
# Loss: 6.770380463463446
# ********************************************
#
# Batch #400 - max 619 words
# Loss: 7.085337050250296
# ********************************************
#
# Batch #401 - max 577 words
# Loss: 7.210156688561489
# ********************************************
#
# Batch #402 - max 206 words
# Loss: 6.691700022311271
# ********************************************
#
# Batch #403 - max 505 words
# Loss: 6.664366545424562
# ********************************************
#
# Batch #404 - max 690 words
# Loss: 7.176267786049131
# ********************************************
#
# Batch #405 - max 590 words
# Loss: 7.2305536861135895
# ********************************************
#
# Batch #406 - max 516 words
# Loss: 7.289140060051393
# ********************************************
#
# Batch #407 - max 655 words
# Loss: 7.26816855572054
# ********************************************
#
# Batch #408 - max 1524 words
# Loss: 7.3368721148228015
# ********************************************
#
# Batch #409 - max 713 words
# Loss: 7.442288994846929
# ********************************************
#
# Batch #410 - max 322 words
# Loss: 6.9413151612249475
# ********************************************
#
# Batch #411 - max 408 words
# Loss: 7.2893622493982555
# ********************************************
#
# Batch #412 - max 426 words
# Loss: 6.880213344113915
# ********************************************
#
# Batch #413 - max 475 words
# Loss: 7.035496645575788
# ********************************************
#
# Batch #414 - max 235 words
# Loss: 7.131248105643449
# ********************************************
#
# Batch #415 - max 435 words
# Loss: 7.097698920838388
# ********************************************
#
# Batch #416 - max 354 words
# Loss: 6.714294179736089
# ********************************************
#
# Batch #417 - max 388 words
# Loss: 6.598244891404978
# ********************************************
#
# Batch #418 - max 354 words
# Loss: 7.177929162629616
# ********************************************
#
# Batch #419 - max 521 words
# Loss: 7.175482080082323
# ********************************************
#
# Batch #420 - max 240 words
# Loss: 6.822053519115966
# ********************************************
#
# Batch #421 - max 465 words
# Loss: 6.797983976523164
# ********************************************
#
# Batch #422 - max 399 words
# Loss: 7.529041725322753
# ********************************************
#
# Batch #423 - max 738 words
# Loss: 7.3899712669004645
# ********************************************
#
# Batch #424 - max 340 words
# Loss: 7.322905608403588
# ********************************************
#
# Batch #425 - max 977 words
# Loss: 7.284854066159953
# ********************************************
#
# Batch #426 - max 309 words
# Loss: 7.1188472581357045
# ********************************************
#
# Batch #427 - max 217 words
# Loss: 6.940074284738513
# ********************************************
#
# Batch #428 - max 443 words
# Loss: 6.868049835054826
# ********************************************
#
# Batch #429 - max 412 words
# Loss: 7.4214769622236325
# ********************************************
#
# Batch #430 - max 610 words
# Loss: 6.5456464122056035
# ********************************************
#
# Batch #431 - max 266 words
# Loss: 6.786800632393401
# ********************************************
#
# Batch #432 - max 476 words
# Loss: 6.796903259266682
# ********************************************
#
# Batch #433 - max 329 words
# Loss: 7.148381368279815
# ********************************************
#
# Batch #434 - max 368 words
# Loss: 6.611091597411456
# ********************************************
#
# Batch #435 - max 264 words
# Loss: 6.617127077551472
# ********************************************
#
# Batch #436 - max 995 words
# Loss: 7.522024845797867
# ********************************************
#
# Batch #437 - max 273 words
# Loss: 7.248051117590059
# ********************************************
#
# Batch #438 - max 662 words
# Loss: 7.35938892669291
# ********************************************
#
# Batch #439 - max 508 words
# Loss: 6.997040804517052
# ********************************************
#
# Batch #440 - max 406 words
# Loss: 7.782550494176886
# ********************************************
#
# Batch #441 - max 639 words
# Loss: 7.059534918407905
# ********************************************
#
# Batch #442 - max 316 words
# Loss: 6.799205711181862
# ********************************************
#
# Batch #443 - max 300 words
# Loss: 6.800571960603588
# ********************************************
#
# Batch #444 - max 483 words
# Loss: 6.866067670128969
# ********************************************
#
# Batch #445 - max 763 words
# Loss: 6.753155828567607
# ********************************************
#
# Batch #446 - max 827 words
# Loss: 7.202671871721751
# ********************************************
#
# Batch #447 - max 183 words
# Loss: 6.953106320252732
# ********************************************
#
# Batch #448 - max 433 words
# Loss: 6.824898767605413
# ********************************************
#
# Batch #449 - max 145 words
# Loss: 6.327107187880726
# ********************************************
#
# Batch #450 - max 186 words
# Loss: 6.574896368611174
# ********************************************
#
# Batch #451 - max 584 words
# Loss: 7.332567805836128
# ********************************************
#
# Batch #452 - max 189 words
# Loss: 6.728292276876515
# ********************************************
#
# Batch #453 - max 477 words
# Loss: 6.856197806956637
# ********************************************
#
# Batch #454 - max 444 words
# Loss: 7.128660789892511
# ********************************************
#
# Batch #455 - max 618 words
# Loss: 7.576824212238338
# ********************************************
#
# Batch #456 - max 373 words
# Loss: 6.9385174871120565
# ********************************************
#
# Batch #457 - max 317 words
# Loss: 7.04578734311182
# ********************************************
#
# Batch #458 - max 244 words
# Loss: 7.121758882908013
# ********************************************
#
# Batch #459 - max 310 words
# Loss: 7.057953310660228
# ********************************************
#
# Batch #460 - max 217 words
# Loss: 6.589510696227108
# ********************************************
#
# Batch #461 - max 663 words
# Loss: 7.261866130645026
# ********************************************
#
# Batch #462 - max 977 words
# Loss: 7.073381103104924
# ********************************************
#
# Batch #463 - max 514 words
# Loss: 6.98554729705512
# ********************************************
#
# Batch #464 - max 746 words
# Loss: 6.919467114058208
# ********************************************
#
# Batch #465 - max 705 words
# Loss: 6.326533221984878
# ********************************************
#
# Batch #466 - max 243 words
# Loss: 6.552259027042311
# ********************************************
#
# Batch #467 - max 228 words
# Loss: 7.4181020248545995
# ********************************************
#
# Batch #468 - max 381 words
# Loss: 6.8764559834092625
# ********************************************
#
# Batch #469 - max 715 words
# Loss: 7.1755101035458475
# ********************************************
#
# Batch #470 - max 210 words
# Loss: 6.615858793432272
# ********************************************
#
# Batch #471 - max 193 words
# Loss: 6.629464776010597
# ********************************************
#
# Batch #472 - max 145 words
# Loss: 6.682263787760543
# ********************************************
#
# Batch #473 - max 656 words
# Loss: 7.128636285560926
# ********************************************
#
# Batch #474 - max 823 words
# Loss: 6.858105382956571
# ********************************************
#
# Batch #475 - max 386 words
# Loss: 6.172693075878043
# ********************************************
#
# Batch #476 - max 372 words
# Loss: 6.7841989097521225
# ********************************************
#
# Batch #477 - max 383 words
# Loss: 6.717997562628294
# ********************************************
#
# Batch #478 - max 241 words
# Loss: 6.8978331228947525
# ********************************************
#
# Batch #479 - max 706 words
# Loss: 6.78329308223938
# ********************************************
#
# Batch #480 - max 202 words
# Loss: 6.6104611418394015
# ********************************************
#
# Batch #481 - max 177 words
# Loss: 7.496201912048374
# ********************************************
#
# Batch #482 - max 545 words
# Loss: 6.668872252164305
# ********************************************
#
# Batch #483 - max 237 words
# Loss: 6.6939961115336315
# ********************************************
#
# Batch #484 - max 391 words
# Loss: 6.991662798089929
# ********************************************
#
# Batch #485 - max 395 words
# Loss: 7.165549248159677
# ********************************************
#
# Batch #486 - max 153 words
# Loss: 6.504092630222372
# ********************************************
#
# Batch #487 - max 526 words
# Loss: 6.810922697315482
# ********************************************
#
# Batch #488 - max 223 words
# Loss: 6.3979750074955035
# ********************************************
#
# Batch #489 - max 206 words
# Loss: 6.289020478876285
# ********************************************
#
# Batch #490 - max 319 words
# Loss: 6.738605451061816
# ********************************************
#
# Batch #491 - max 338 words
# Loss: 6.875804271200809
# ********************************************
#
# Batch #492 - max 949 words
# Loss: 7.574664797552912
# ********************************************
#
# Batch #493 - max 648 words
# Loss: 7.023895640527876
# ********************************************
#
# Batch #494 - max 703 words
# Loss: 6.85124364236717
# ********************************************
#
# Batch #495 - max 290 words
# Loss: 6.521262271408053
# ********************************************
#
# Batch #496 - max 166 words
# Loss: 7.0631446165110106
# ...
#
# Batch #1838 - max 414 words
# Loss: 6.305646799724638
# ********************************************
#
# Batch #1839 - max 505 words
# Loss: 6.17121973280557
# ********************************************
#
# Batch #1840 - max 271 words
# Loss: 6.076555114496499
# ********************************************
#
# Batch #1841 - max 472 words
# Loss: 5.8118861837155125
# ********************************************
#
# Batch #1842 - max 777 words
# Loss: 5.993714479231794
# ********************************************
#
# Batch #1843 - max 294 words
# Loss: 7.1401957586755715
# ********************************************
#
# Batch #1844 - max 427 words
# Loss: 6.879413326916201
# ********************************************
#
# Batch #1845 - max 359 words
# Loss: 7.1139930416032655
# ********************************************
#
# Batch #1846 - max 151 words
# Loss: 6.2196860888920735
# ********************************************
#
# Batch #1847 - max 419 words
# Loss: 6.3470014537436565
# ********************************************
#
# Batch #1848 - max 324 words
# Loss: 6.089076321777498
# ********************************************
#
# Batch #1849 - max 492 words
# Loss: 6.1130882273642175
# ********************************************
#
# Batch #1850 - max 327 words
# Loss: 5.939778378868072
# ********************************************
#
# Batch #1851 - max 262 words
# Loss: 5.748339439920697
# ********************************************
#
# Batch #1852 - max 391 words
# Loss: 6.464126197952361
# ********************************************
#
# Batch #1853 - max 355 words
# Loss: 6.467668283660066
# ********************************************
#
# Batch #1854 - max 634 words
# Loss: 6.8653402229790235
# ********************************************
#
# Batch #1855 - max 332 words
# Loss: 6.45075134479383
# ********************************************
#
# Batch #1856 - max 380 words
# Loss: 6.5524478178379475
# ********************************************
#
# Batch #1857 - max 247 words
# Loss: 6.41511151548754
# ********************************************
#
# Batch #1858 - max 785 words
# Loss: 6.4995030867526
# ********************************************
#
# Batch #1859 - max 735 words
# Loss: 6.782467864267765
# ********************************************
#
# Batch #1860 - max 418 words
# Loss: 6.411802718223583
# ********************************************
#
# Batch #1861 - max 453 words
# Loss: 6.6679004364565335
# ********************************************
#
# Batch #1862 - max 378 words
# Loss: 6.19753375070063
# ********************************************
#
# Batch #1863 - max 204 words
# Loss: 6.553139834257161
# ********************************************
#
# Batch #1864 - max 718 words
# Loss: 6.4611380781591565
# ********************************************
#
# Batch #1865 - max 188 words
# Loss: 7.290524848959741
# ********************************************
#
# Batch #1866 - max 289 words
# Loss: 6.062685578635939
# ********************************************
#
# Batch #1867 - max 364 words
# Loss: 6.139416872183088
# ********************************************
#
# Batch #1868 - max 392 words
# Loss: 6.269080270360711
# ********************************************
#
# Batch #1869 - max 571 words
# Loss: 6.437934985190493
# ********************************************
#
# Batch #1870 - max 404 words
# Loss: 6.34776921059694
# ********************************************
#
# Batch #1871 - max 283 words
# Loss: 6.054843145632241
# ********************************************
#
# Batch #1872 - max 531 words
# Loss: 6.516363653769688
# ********************************************
#
# Batch #1873 - max 220 words
# Loss: 6.57329318911024
# ********************************************
#
# Batch #1874 - max 310 words
# Loss: 6.06346258066053
# ********************************************
#
# Batch #1875 - max 901 words
# Loss: 6.121106508579229
# ********************************************
#
# Batch #1876 - max 462 words
# Loss: 6.313201575880436
# ********************************************
#
# Batch #1877 - max 438 words
# Loss: 6.050350961675766
# ********************************************
#
# Batch #1878 - max 422 words
# Loss: 5.83693521197818
# ********************************************
#
# Batch #1879 - max 556 words
# Loss: 6.594578755407575
# ********************************************
#
# Batch #1880 - max 966 words
# Loss: 6.699606562686341
# ********************************************
#
# Batch #1881 - max 396 words
# Loss: 6.240711482365312
# ********************************************
#
# Batch #1882 - max 628 words
# Loss: 6.622907236040222
# ********************************************
#
# Batch #1883 - max 146 words
# Loss: 6.1727176786204065
# ********************************************
#
# Batch #1884 - max 692 words
# Loss: 6.687954896136062
# ********************************************
#
# Batch #1885 - max 416 words
# Loss: 6.914300678513704
# ********************************************
#
# Batch #1886 - max 451 words
# Loss: 6.828151962711609
# ********************************************
#
# Batch #1887 - max 274 words
# Loss: 6.557685727332066
# ********************************************
#
# Batch #1888 - max 189 words
# Loss: 6.200817155245611
# ********************************************
#
# Batch #1889 - max 464 words
# Loss: 7.363915993953051
# ********************************************
#
# Batch #1890 - max 459 words
# Loss: 6.537860648978485
# ********************************************
#
# Batch #1891 - max 827 words
# Loss: 6.454525512507654
# ********************************************
#
# Batch #1892 - max 186 words
# Loss: 6.32271742229401
# ********************************************
#
# Batch #1893 - max 258 words
# Loss: 6.4696955213511655
# ********************************************
#
# Batch #1894 - max 267 words
# Loss: 5.962676636866594
# ********************************************
#
# Batch #1895 - max 481 words
# Loss: 6.483926190827981
# ********************************************
#
# Batch #1896 - max 354 words
# Loss: 5.9624979837187055
# ********************************************
#
# Batch #1897 - max 995 words
# Loss: 6.39144960855052
# ********************************************
#
# Batch #1898 - max 299 words
# Loss: 6.398980747862051
# ********************************************
#
# Batch #1899 - max 263 words
# Loss: 6.685429915718934
# ********************************************
#
# Batch #1900 - max 185 words
# Loss: 6.290128192526444
# ********************************************
#
# Batch #1901 - max 980 words
# Loss: 6.417311697021077
# ********************************************
#
# Batch #1902 - max 946 words
# Loss: 6.801643462248586
# ********************************************
#
# Batch #1903 - max 287 words
# Loss: 5.667706004435434
# ********************************************
#
# Batch #1904 - max 735 words
# Loss: 6.508200601522505
# ********************************************
#
# Batch #1905 - max 186 words
# Loss: 5.959464700941316
# ********************************************
#
# Batch #1906 - max 268 words
# Loss: 6.4514803994612
# ********************************************
#
# Batch #1907 - max 704 words
# Loss: 6.480827603286097
# ********************************************
#
# Batch #1908 - max 586 words
# Loss: 6.982968079501955
# ********************************************
#
# Batch #1909 - max 159 words
# Loss: 6.113663178700715
# ********************************************
#
# Batch #1910 - max 336 words
# Loss: 6.468905634910765
# ********************************************
#
# Batch #1911 - max 773 words
# Loss: 6.669169323227026
# ********************************************
#
# Batch #1912 - max 283 words
# Loss: 6.05901316742315
# ********************************************
#
# Batch #1913 - max 220 words
# Loss: 6.004699085045782
# ********************************************
#
# Batch #1914 - max 460 words
# Loss: 6.94055827004697
# ********************************************
#
# Batch #1915 - max 356 words
# Loss: 6.542291846291597
# ********************************************
#
# Batch #1916 - max 209 words
# Loss: 6.772272888202708
# ********************************************
#
# Batch #1917 - max 473 words
# Loss: 6.270855666449173
# ********************************************
#
# Batch #1918 - max 561 words
# Loss: 6.117294062946786
# ********************************************
#
# Batch #1919 - max 200 words
# Loss: 6.112937013575957
# ********************************************
#
# Batch #1920 - max 346 words
# Loss: 6.437725040980287
# ********************************************
#
# Batch #1921 - max 173 words
# Loss: 6.500452907937826
# ********************************************
#
# Batch #1922 - max 587 words
# Loss: 6.7410885602230755
# ********************************************
#
# Batch #1923 - max 232 words
# Loss: 6.6971825193637216
# ********************************************
#
# Batch #1924 - max 517 words
# Loss: 6.6139839258513655
# ********************************************
#
# Batch #1925 - max 171 words
# Loss: 5.961881697204335
# ********************************************
#
# Batch #1926 - max 368 words
# Loss: 6.034577069247854
# ********************************************
#
# Batch #1927 - max 264 words
# Loss: 6.938362228785909
# ********************************************
#
# Batch #1928 - max 510 words
# Loss: 7.587802836106693
# ********************************************
#
# Batch #1929 - max 498 words
# Loss: 6.645526811019167
# ********************************************
#
# Batch #1930 - max 128 words
# Loss: 6.112357272844188
# ********************************************
#
# Batch #1931 - max 632 words
# Loss: 6.426045170851745
# ********************************************
#
# Batch #1932 - max 548 words
# Loss: 7.08894707255802
# ********************************************
#
# Batch #1933 - max 160 words
# Loss: 6.843414336386876
# ********************************************
#
# Batch #1934 - max 463 words
# Loss: 6.424381958341972
# ********************************************
#
# Batch #1935 - max 233 words
# Loss: 6.4424603051858025
# ********************************************
#
# Batch #1936 - max 353 words
# Loss: 6.650365618368022
# ********************************************
#
# Batch #1937 - max 600 words
# Loss: 7.520744959797289
# ********************************************
#
# Batch #1938 - max 447 words
# Loss: 6.925184496333666
# ********************************************
#
# Batch #1939 - max 249 words
# Loss: 7.157816820911767
# ********************************************
#
# Batch #1940 - max 265 words
# Loss: 6.3745332855551
# ********************************************
#
# Batch #1941 - max 392 words
# Loss: 6.379983291809077
# ********************************************
#
# Batch #1942 - max 265 words
# Loss: 6.212674665197309
# ********************************************
#
# Batch #1943 - max 397 words
# Loss: 6.681196357914797
# ********************************************
#
# Batch #1944 - max 320 words
# Loss: 6.444463580998394
# ********************************************
#
# Batch #1945 - max 478 words
# Loss: 6.443891356656056
# ********************************************
#
# Batch #1946 - max 411 words
# Loss: 6.261606295249058
# ********************************************
#
# Batch #1947 - max 188 words
# Loss: 6.074536361162691
# ********************************************
#
# Batch #1948 - max 298 words
# Loss: 6.19207107628333
# ********************************************
#
# Batch #1949 - max 354 words
# Loss: 6.600378999855166
# ********************************************
#
# Batch #1950 - max 637 words
# Loss: 6.534839940956128
# ********************************************
#
# Batch #1951 - max 961 words
# Loss: 6.142411255319328
# ********************************************
#
# Batch #1952 - max 183 words
# Loss: 6.185053689213064
# ********************************************
#
# Batch #1953 - max 779 words
# Loss: 6.19854867427814
# ********************************************
#
# Batch #1954 - max 206 words
# Loss: 6.153638404028207
# ********************************************
#
# Batch #1955 - max 189 words
# Loss: 6.253895607232489
# ********************************************
#
# Batch #1956 - max 282 words
# Loss: 6.680271747097474
# ********************************************
#
# Batch #1957 - max 302 words
# Loss: 6.476609554698035
# ********************************************
#
# Batch #1958 - max 315 words
# Loss: 6.253130525451645
# ********************************************
#
# Batch #1959 - max 238 words
# Loss: 6.4724620431712365
# ********************************************
#
# Batch #1960 - max 217 words
# Loss: 6.169922863299466
# ********************************************
#
# Batch #1961 - max 303 words
# Loss: 6.208219845581354
# ********************************************
#
# Batch #1962 - max 563 words
# Loss: 6.389181645981468
# ********************************************
#
# Batch #1963 - max 672 words
# Loss: 6.502611451829704
# ********************************************
#
# Batch #1964 - max 919 words
# Loss: 6.4972933776295285
# ********************************************
#
# Batch #1965 - max 528 words
# Loss: 7.153644207978238
# ********************************************
#
# Batch #1966 - max 671 words
# Loss: 7.496207057195265
# ********************************************
#
# Batch #1967 - max 408 words
# Loss: 6.749955759702749
# ********************************************
#
# Batch #1968 - max 523 words
# Loss: 6.66194316084636
# ********************************************
#
# Batch #1969 - max 231 words
# Loss: 7.175192616836107
# ********************************************
#
# Batch #1970 - max 406 words
# Loss: 6.819617967869096
# ********************************************
#
# Batch #1971 - max 182 words
# Loss: 6.378672337518506
# ********************************************
#
# Batch #1972 - max 299 words
# Loss: 6.535707690693124
# ********************************************
#
# Batch #1973 - max 263 words
# Loss: 5.848394868786587
# ********************************************
#
# Batch #1974 - max 486 words
# Loss: 6.34608186452824
# ********************************************
#
# Batch #1975 - max 228 words
# Loss: 6.473887826390528
# ********************************************
#
# Batch #1976 - max 384 words
# Loss: 7.126362789997005
# ********************************************
#
# Batch #1977 - max 530 words
# Loss: 6.734428434539369
# ********************************************
#
# Batch #1978 - max 320 words
# Loss: 6.819353700022008
# ********************************************
#
# Batch #1979 - max 995 words
# Loss: 6.920714716740207
# ********************************************
#
# Batch #1980 - max 219 words
# Loss: 6.479331047582212
# ********************************************
#
# Batch #1981 - max 314 words
# Loss: 6.861416557350433
# ********************************************
#
# Batch #1982 - max 641 words
# Loss: 6.605298198400847
# ********************************************
#
# Batch #1983 - max 876 words
# Loss: 6.567550253472603
# ********************************************
#
# Batch #1984 - max 304 words
# Loss: 6.867148619915325
# ********************************************
#
# Batch #1985 - max 363 words
# Loss: 6.966181256652428
# ********************************************
#
# Batch #1986 - max 407 words
# Loss: 6.065384327437812
# ********************************************
#
# Batch #1987 - max 501 words
# Loss: 6.644711092913445
# ********************************************
#
# Batch #1988 - max 303 words
# Loss: 6.500732061823795
# ********************************************
#
# Batch #1989 - max 215 words
# Loss: 6.732037982264611
# ********************************************
#
# Batch #1990 - max 281 words
# Loss: 6.544476666203576
# ********************************************
#
# Batch #1991 - max 641 words
# Loss: 6.255913412895136
# ********************************************
#
# Batch #1992 - max 323 words
# Loss: 6.538774121306518
# ********************************************
#
# Batch #1993 - max 472 words
# Loss: 6.492822610073304
# ********************************************
#
# Batch #1994 - max 287 words
# Loss: 6.280902927489825
# ********************************************
#
# Batch #1995 - max 242 words
# Loss: 5.902685437178024
# ********************************************
#
# Batch #1996 - max 333 words
# Loss: 6.6990168226737214
# ********************************************
#
# Batch #1997 - max 215 words
# Loss: 6.615615122286802
# ********************************************
#
# Batch #1998 - max 687 words
# Loss: 6.7356592951205325
# ********************************************
#
# Batch #1999 - max 421 words
# Loss: 6.027136517618263
# ********************************************
#
# Batch #2000 - max 216 words
# Loss: 6.091777668923983
# ********************************************

# %%
input = ['<START>', 'what', 'is', 'the', 'best', 'movie', 'genre','<END>']

# input = ['<START>', 'because', 'of', 'all', 'the', 'controversy']

output = testRNN.generateOutput(input, 20)

print(output)
# Out:
# ['<START>', 'what', 'is', 'the', 'best', 'movie', 'genre', '<END>', 'and', 'br', 'the', 'br', 'film', 'br', 'is', 'br', 'a', 'br', 'film', 'br', 'the', 'br', 'film', 'br', 'is', 'br', 'a', 'br']

# %%
testRNN.layers['hiddenLayer1'].beta1**testRNN.layers['hiddenLayer1'].t
# Out:
# 1.9398282331131582e-101

# %%
filePath = 'C:/Users/josep/Desktop/Self/Learning/NLP/RNN/Model/'

for layerName in testRNN.layers.keys():
    currLayer = testRNN.layers[layerName]
    layerWeights = currLayer.layerWeights
    np.save(filePath + layerName + '_layerWeights.npy', layerWeights)
    
    if currLayer.rnn:
        timeWeights = currLayer.timeWeights
        np.save(filePath + layerName + '_timeWeights.npy', timeWeights)
    bias = currLayer.bias
    np.save(filePath + layerName + '_bias.npy', bias)

# %%
recreatedRNN = baseRNN.neuralNet(embeddings=embeddings, word2ind=word2ind, outputActivation='softmax',
                    hiddenLayerShapes=[100,100,100], hiddenLayerActivations=['relu', 'relu', 'relu'],
                    lossFunction='crossEntropyLoss', learningRate=.0005, epochs=1, batchSize=5,
                    adam=True, clipVal=1, debug=False)


for layerName in recreatedRNN.layers.keys():
    currLayer = recreatedRNN.layers[layerName]

    currLayer.layerWeights = np.load(filePath + layerName + '_layerWeights.npy')
    
    if currLayer.rnn:
        currLayer.timeWeights = np.load(filePath + layerName + '_timeWeights.npy')

    currLayer.bias = np.load(filePath + layerName + '_bias.npy')

# %%
input = ['<START>', 'what', 'is', 'the', 'best', 'movie', 'genre','<END>']

# input = ['<START>', 'because', 'of', 'all', 'the', 'controversy']

output = recreatedRNN.generateOutput(input, 20)

print(output)
# Out:
# ['<START>', 'what', 'is', 'the', 'best', 'movie', 'genre', '<END>', 'and', 'br', 'the', 'br', 'film', 'br', 'is', 'br', 'a', 'br', 'film', 'br', 'the', 'br', 'film', 'br', 'is', 'br', 'a', 'br']
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
